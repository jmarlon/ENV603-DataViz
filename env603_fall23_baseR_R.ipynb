# %% [markdown]
# <a href="https://colab.research.google.com/github/jmarlon/ENV603-DataViz/blob/main/env603_fall23_baseR_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
biomass <- data.frame(Group = c('Plants', 'Bacteria', 'Fungi', 'Archaea', 'Protists',
'Viruses', 'Animals'),Carbon = c(450, 70, 12, 8, 4, 0.2, 2))

# %%
biomass

# %%
dat <- read.table('http://www.intro2r.info/data/apples.txt', sep = '\t', header = TRUE)
dat

# %%
barplot(dat$Apple_production_tonnes)
# Out:
# plot without title

# %%
barplot(biomass$Carbon)
# Out:
# plot without title
